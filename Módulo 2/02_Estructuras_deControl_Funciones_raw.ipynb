# %% [markdown]
# # 🐍 **Introducción a las estructuras de control y funciones en Python**

# %% [markdown]
# En este notebook trabajaremos con las **estructuras de control** más importantes en Python y veremos cómo, a partir de ellas, podemos organizar mejor nuestro código usando **funciones**.

# %% [markdown]
# ### 🔜 **Introducción**

# %% [markdown]
# #### 📌 **Objetivos de la sesión**

# %% [markdown]
# - Comprender y aplicar condicionales (`if`, `elif`, `else`) para tomar decisiones en el programa.
# - Usar ciclos (`while`, `for`) para repetir instrucciones de manera controlada.
# - Aprender el uso de sentencias de control como `break` y `continue`.
# - Adoptar **buenas prácticas** para evitar la repetición de código.
# - Introducir el concepto de **funciones** para estructurar y reutilizar el código.

# %% [markdown]
# #### 🛠️ **¿Qué veremos?**

# %% [markdown]
# 1. Condicionales
# 2. Ciclo `while`
# 3. Ciclo `for`
# 4. Buenas prácticas y motivación para funciones
# 5. Definición y uso de funciones
#
# Al final de esta sesión, serás capaz de escribir programas que **tomen decisiones, repitan procesos y organicen el código en bloques reutilizables**.

# %% [markdown]
# ### 🎛️ **Condicionales**

# %% [markdown]
# En programación, muchas veces necesitamos que el código tome decisiones dependiendo de ciertas condiciones. Para eso usamos **estructuras condicionales**.
#
# En Python, la instrucción `if` nos permite ejecutar un bloque de código **solo si una condición es verdadera**. También podemos usar `else` y `elif` (else if) para manejar diferentes escenarios.

# %% [markdown]
# 🧠 **Sintaxis básica**
#
# ```python
# if condición:
#     # bloque si la condición es verdadera
# elif otra_condición:
#     # bloque si la primera fue falsa pero esta es verdadera
# else:
#     # bloque si ninguna condición fue verdadera

# %%
# Ejemplo 1: Determinar si un número es positivo, negativo o cero

# %%
# Ejemplo 2: Clasificación de edades

# %%
# Ejemplo 3: Verificar si un número está en un rango

# %% [markdown]
# ### ➰ **Ciclos**

# %% [markdown]
# Los **ciclos (o bucles)** permiten ejecutar un bloque de código varias veces sin necesidad de repetirlo manualmente. Son fundamentales cuando trabajamos con repeticiones, conteos o recorridos de datos.
#
# En Python, los ciclos más comunes son `while` y `for`.

# %% [markdown]
# ##### 🔁 **Ciclo `while`**

# %% [markdown]
# El ciclo `while` se ejecuta **mientras una condición sea verdadera**. Es importante asegurarse de que la condición cambie en algún momento, para evitar ciclos infinitos.

# %% [markdown]
# 📌 **Sintaxis básica**
#
# ```python
# while condición:
#     # bloque de código

# %%
# Ejemplo 1: Contar del 1 al 5

# %%
# Ejemplo 2: Pedir números hasta que el usuario escriba "salir"

# %%
# Ejemplo 3: Usando break y continue

# %% [markdown]
# ##### 🔂 **Ciclo `for` en Python**

# %% [markdown]
# El ciclo `for` se utiliza para **recorrer elementos de una secuencia**, como listas, cadenas de texto o rangos de números.

# %% [markdown]
# 📌 **Sintaxis básica**
#
# ```python
# for variable in secuencia:
#     # bloque de código

# %%
# Ejemplo 1: Recorrer un rango

# %%
# Ejemplo 2: Recorrer una lista

# %%
# Ejemplo 3: Recorrer una cadena

# %%
# Ejemplo 4: Usar enumerate

# %%
# Ejemplo 5: Usar zip

# %% [markdown]
# ### ✨ **Funciones**

# %% [markdown]
# 🚫 **El problema**

# %% [markdown]
# Imaginemos que queremos **sumar los números de una lista** en varios lugares del programa.
# Podríamos **copiar y pegar el mismo código** una y otra vez...
# pero eso **NO es buena práctica** ❌

# %% [markdown]
# ✅ **La solución**

# %% [markdown]
# En lugar de repetirnos, podemos **definir una función** que realice esa tarea y luego llamarla cuando la necesitemos.
# Así nuestro código es más:
#
# - 📖 **Legible**
# - 🔁 **Reutilizable**
# - 🛠️ **Fácil de mantener**

# %% [markdown]
# 🔧 **Sintaxis básica de una función en Python**
#
# ```python
# def nombre_de_la_funcion(parámetros):
#     # bloque de código
#     return resultado

# %% [markdown]
# 🐍 **Funciones en Python**

# %%
# Ejemplo 1: Función sin parámetros

# %%
# Ejemplo 2: Función con parámetros

# %%
# Ejemplo 3: Función con bucles internos

# %%
# Ejemplo 4: Función con valor por defecto

# %%
# Ejemplo 5: Simulación de menú con funciones

# %% [markdown]
# ### 🤹🏻‍♀️ **Manejo de errores**

# %% [markdown]
# En programación, es común que ocurran errores **durante la ejecución** de un programa: archivos que no existen, divisiones entre cero, datos incorrectos, índices fuera de rango, entre otros.
#
# Si no gestionamos estos errores, el programa se detiene bruscamente. Aquí es donde entra el uso de `try/except`.

# %% [markdown]
# 🎯 **Objetivo del bloque `try/except`**

# %% [markdown]
# Permite **atrapar y manejar errores** de forma controlada, evitando que el programa se caiga inesperadamente. Así podemos:
#
# - Dar mensajes más amigables al usuario
# - Saltar operaciones problemáticas sin detener todo el programa
# - Registrar o depurar errores de forma más limpia
# - Mantener la ejecución del resto del código

# %% [markdown]
# 🔍 **Estructura básica**

# %% [markdown]
# ```python
# try:
#     # Código que puede causar error
# except TipoDeError:
#     # Código que se ejecuta si ocurre ese error

# %%
print("Intentando dividir dos números...")

# %%
# CAPTURA DE CUALQUIER EXCEPCIÓN
print("\nIntentando convertir entrada a entero...")

# %%
# USO DE ELSE Y FINALLY

print("\nIntentando acceso a lista con índice...")

# %%
# 4. MANEJO DE MÚLTIPLES EXCEPCIONES
print("\nValidando operación múltiple...")

# %% [markdown]
# ### 💪🏻 **Ejercicios**

# %% [markdown]
# ##### Ejercicio 1

# %% [markdown]
# Pide al usuario un número entero y determina si es par o impar usando una función.

# %% [markdown]
# ✅ **Ejemplo de entrada y salida esperada**
#
# ```plaintext
# Número: 7
#
# El número 7 es impar.

# %%
# HAZ TU SCRIPT ACÁ

# %% [markdown]
# ##### Ejercicio 2

# %% [markdown]
# El programa elige un número entre 1 y 10. El usuario tiene 3 intentos para adivinarlo. Usa funciones y condicionales.

# %% [markdown]
# ✅ **Ejemplo de entrada y salida esperada**
#
# ```plaintext
# Adivina el número (entre 1 y 10): 5
# Intenta otra vez.
# Adivina el número (entre 1 y 10): 3
# ¡Correcto! El número era 3.

# %%
# HAZ TU SCRIPT ACÁ

# %% [markdown]
# ##### Ejercicio 3

# %% [markdown]
# Crea una función que reciba dos números y una operación (`+`, `-`, `*`, `/`) e imprima el resultado. Usa `try/except` para manejar divisiones por cero y errores de entrada.

# %% [markdown]
# ✅ **Ejemplo de entrada y salida esperada**
#
# ```plaintext
# Número 1: 8
# Número 2: 0
# Operación (+, -, *, /): /
#
# Error: No se puede dividir por cero.

# %%
# HAZ TU SCRIPT ACÁ

# %% [markdown]
# ##### Ejercicio 4

# %% [markdown]
# Crea una función que verifique si una contraseña es segura. Debe tener:
#
# - al menos 8 caracteres
#
# - al menos una letra mayúscula
#
# - al menos un número
#
# - Si no cumple, mostrar los motivos.

# %% [markdown]
# ✅ **Ejemplo de entrada y salida esperada**
#
# ```plaintext
# Contraseña: datos2026
#
# Tu contraseña no es segura:
# - Debe tener al menos una letra mayúscula.

# %%
# HAZ TU SCRIPT ACÁ
