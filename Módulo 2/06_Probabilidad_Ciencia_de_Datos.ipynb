# %% [markdown]
# # **📊 Probabilidad para Ciencia de Datos**

# %% [markdown]
# ### **🎯 Introducción**

# %% [markdown]
# En Ciencia de Datos trabajamos constantemente con **incertidumbre**.
#
# La probabilidad es la herramienta matemática que nos permite:
#
# - 📌 Modelar eventos aleatorios
# - 📉 Cuantificar riesgo
# - 🧠 Tomar decisiones basadas en datos
# - 🤖 Construir modelos predictivos
#
# En esta sesión estudiaremos los conceptos fundamentales de probabilidad con un enfoque aplicado y computacional.

# %% [markdown]
# ### **🎲 1. Fundamentos de Probabilidad**

# %% [markdown]
# Un experimento aleatorio es un proceso cuyo resultado no puede predecirse con certeza.
#
# La probabilidad puede interpretarse como **frecuencia relativa** cuando repetimos el experimento muchas veces.

# %%
import numpy as np

# %%
np.random.seed(42)

lanzamientos = np.random.choice(["cara", "sello"], size=10000)
prob_cara = np.mean(lanzamientos == "cara")

prob_cara
# Out:
# np.float64(0.5013)

# %% [markdown]
# ### **🔎 2. Probabilidad Condicional**

# %% [markdown]
# La probabilidad condicional mide la probabilidad de un evento A dado que ocurrió B.
#
# Es fundamental en:
#
# - 🏥 Diagnóstico médico
# - 📧 Clasificación de spam
# - 📊 Modelos predictivos

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(0)

n = 1000

data = pd.DataFrame({
    "enfermedad": np.random.choice([0,1], size=n, p=[0.9,0.1]),
})

data["test_positivo"] = np.where(
    data["enfermedad"] == 1,
    np.random.choice([0,1], size=n, p=[0.2,0.8]),
    np.random.choice([0,1], size=n, p=[0.9,0.1])
)

p_cond = (
    data[(data["enfermedad"] == 1) & (data["test_positivo"] == 1)].shape[0] /
    data[data["test_positivo"] == 1].shape[0]
)

p_cond
# Out:
# 0.4497354497354497

# %% [markdown]
# ### **🧠 3. Teorema de Bayes**

# %% [markdown]
# $$P(A | B) = \frac{P(B | A) · P(A)}{P(B)}$$
#
# Nos permite actualizar probabilidades cuando obtenemos nueva información.
#
# Es la base de modelos como **Naive Bayes**.

# %%
p_A = data["enfermedad"].mean()
p_B_given_A = data[data["enfermedad"] == 1]["test_positivo"].mean()
p_B = data["test_positivo"].mean()

bayes = (p_B_given_A * p_A) / p_B

bayes
# Out:
# np.float64(0.44973544973544977)

# %% [markdown]
# ### **🎯 4. Variable Aleatoria Binomial**

# %% [markdown]
# Modela el número de éxitos en n intentos independientes con probabilidad p.
#
# Es fundamental para entender tasas de conversión, clics y eventos binarios.

# %%
n_experimentos = 1000
n_intentos = 20
p = 0.3

simulaciones = np.random.binomial(n_intentos, p, size=n_experimentos)

simulaciones[:10]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(simulaciones, bins=15)
plt.xlabel("Número de éxitos")
plt.ylabel("Frecuencia")
plt.title("Simulación Binomial")
plt.show()

# %% [markdown]
# ### **📈 5. Distribución Normal y Teorema Central del Límite**

# %% [markdown]
# Los promedios de muestras tienden a distribuirse normalmente, incluso si la variable original no es normal.
#
# Este resultado explica por qué la distribución normal aparece constantemente en Ciencia de Datos.

# %%
muestras = []

for _ in range(1000):
    muestra = np.random.exponential(scale=2, size=50)
    muestras.append(np.mean(muestra))

muestras = np.array(muestras)

plt.hist(muestras, bins=30)
plt.xlabel("Promedio de la muestra")
plt.ylabel("Frecuencia")
plt.title("Aproximación a Normal (TCL)")
plt.show()

# %% [markdown]
# ### **✅ Conclusiones**

# %% [markdown]
# En esta sesión vimos:
#
# - 🎲 Interpretación frecuentista
# - 🔎 Probabilidad condicional
# - 🧠 Teorema de Bayes
# - 🎯 Distribución binomial
# - 📈 Intuición del Teorema Central del Límite
#
# Estos conceptos son fundamentales en Machine Learning e Inferencia Estadística.
